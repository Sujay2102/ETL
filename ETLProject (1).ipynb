# %%
import pandas as pd
import mysql.connector
#Csv files
orders_df=pd.read_csv("C:\\Users\\patil\\Downloads\\projects_files\\orders_data.csv")
users_df=pd.read_csv("C:\\Users\\patil\\Downloads\\projects_files\\users_data.csv")
Products_df=pd.read_csv("C:\\Users\\patil\\Downloads\\projects_files\\products_data.csv")
#Products_df.head()
#Excel files
payments_df=pd.read_excel("C:\\Users\\patil\\Downloads\\projects_files\\payments_data.xlsx",engine="openpyxl")
reviews_df=pd.read_excel("C:\\Users\\patil\\Downloads\\projects_files\\reviews_data.xlsx",engine="openpyxl")
orders_df.head()
reviews_df.head()
print(Products_df)
print("Extract Successful")
# Out:
#       ProductName                  Description   Price StockQuantity  \
# 0   Contraption A                          NaN    free       unknown
# 1          Tool B         A high-quality tool.  230.23           160
# 2       Machine C    A high-quality apparatus.   56.75            96
# 3        Device D                          NaN   191.7           472
# 4   Contraption E       A high-quality gadget.  337.73           233
# 5     Appliance F    A high-quality appliance.   336.3           180
# 6         Gizmo G                          NaN  299.74           113
# 7   Contraption H       A high-quality gadget.  144.61           318
# 8       Machine I    A high-quality appliance.  285.01       unknown
# 9        Device J                          NaN  197.63           497
# 10         Tool K         A high-quality tool.    free           442
# 11      Machine L      A high-quality machine.  486.14            52
# 12      Machine M                          NaN  425.97           268
# 13        Gizmo N  A high-quality contraption.  363.65           295
# 14    Apparatus O   A high-quality instrument.  125.63           386
# 15       Device P                          NaN  135.47           387
# 16       Gadget Q      A high-quality machine.   29.81       unknown
# 17      Machine R       A high-quality device.  358.22           113
# 18    Apparatus S                          NaN   64.34           101
# 19       Gadget T       A high-quality gadget.  225.27           113
# 20       Device U       A high-quality device.    free           440
# 21       Widget V                          NaN  108.84            81
# 22    Appliance W      A high-quality machine.  448.92           187
# 23    Apparatus X    A high-quality appliance.  242.93           113
# 24   Instrument Y                          NaN  286.01       unknown
# 25       Widget Z   A high-quality instrument.   350.8             2
# 26    Appliance A   A high-quality instrument.   78.27           130
# 27        Gizmo B                          NaN  306.16           220
# 28  Contraption C       A high-quality widget.  274.52            54
# 29         Tool D   A high-quality instrument.   109.5           343
# 30   Instrument E                          NaN    free           485
# 31        Gizmo F  A high-quality contraption.     472           224
# 32       Device G   A high-quality instrument.  303.44       unknown
# 33        Gizmo H                          NaN  350.44           225
# 34  Contraption I      A high-quality machine.  441.43           385
# 35       Device J       A high-quality widget.  315.93           403
# 36   Instrument K                          NaN  154.86           126
# 37  Contraption L      A high-quality machine.   61.69           130
# 38       Gadget M      A high-quality machine.   233.7            53
# 39         Tool N                          NaN  117.04           172
# 40   Instrument O        A high-quality gizmo.    free       unknown
# 41       Gadget P       A high-quality widget.  214.09           218
# 42    Appliance Q                          NaN  442.81           160
# 43   Instrument R      A high-quality machine.  168.93           198
# 44    Appliance S        A high-quality gizmo.   69.82           416
# 45       Device T                          NaN  184.59           247
# 46       Gadget U        A high-quality gizmo.  454.35           324
# 47         Tool V       A high-quality widget.  143.34           439
# 48  Contraption W                          NaN  327.37       unknown
# 49      Machine X       A high-quality device.   10.25           203
# 50        Gizmo Y    A high-quality appliance.    free           184
# 51       Widget Z                          NaN  182.76           123
# 52         Tool A  A high-quality contraption.  159.34           401
# 53       Gadget B    A high-quality appliance.   90.68           255
# 54      Machine C                          NaN   271.7           294
# 55         Tool D   A high-quality instrument.  247.57           280
# 56       Gadget E  A high-quality contraption.  349.29       unknown
# 57    Apparatus F                          NaN  142.01           325
# 58    Apparatus G   A high-quality instrument.  129.62           372
# 59    Appliance H      A high-quality machine.   92.46            98
#
#         Category
# 0            NaN
# 1      Apparatus
# 2      Apparatus
# 3        Widgets
# 4    Instruments
# 5            NaN
# 6      Apparatus
# 7         Gizmos
# 8          Tools
# 9          Tools
# 10           NaN
# 11        Gizmos
# 12    Appliances
# 13        Gizmos
# 14        Gizmos
# 15           NaN
# 16         Tools
# 17  Contraptions
# 18         Tools
# 19   Instruments
# 20           NaN
# 21       Widgets
# 22      Machines
# 23  Contraptions
# 24       Gadgets
# 25           NaN
# 26      Machines
# 27       Widgets
# 28   Instruments
# 29   Instruments
# 30           NaN
# 31       Gadgets
# 32  Contraptions
# 33    Appliances
# 34        Gizmos
# 35           NaN
# 36  Contraptions
# 37    Appliances
# 38   Instruments
# 39         Tools
# 40           NaN
# 41       Widgets
# 42       Gadgets
# 43       Widgets
# 44       Devices
# 45           NaN
# 46       Devices
# 47  Contraptions
# 48   Instruments
# 49   Instruments
# 50           NaN
# 51        Gizmos
# 52        Gizmos
# 53        Gizmos
# 54         Tools
# 55           NaN
# 56      Machines
# 57     Apparatus
# 58      Machines
# 59       Widgets
# Extract Successful

# %%
#Products table
Products_df=Products_df.fillna({
    'Description':"No Description",
    'Category':"Miscellaneous"
})
Products_df['Price']=pd.to_numeric(Products_df['Price'],errors='coerce').fillna(0.0).round(2)
#to_numeric=changes datatype to number
#errors='coerce'-will show as NaN  where value is not numeric
#NaN-Null,fillna-will replace the NaN with 0
Products_df['StockQuantity'] = pd.to_numeric(Products_df['StockQuantity'], errors = 'coerce').fillna(0).round(0)
print(Products_df)
# Out:
#       ProductName                  Description   Price  StockQuantity  \
# 0   Contraption A               No Description    0.00            0.0
# 1          Tool B         A high-quality tool.  230.23          160.0
# 2       Machine C    A high-quality apparatus.   56.75           96.0
# 3        Device D               No Description  191.70          472.0
# 4   Contraption E       A high-quality gadget.  337.73          233.0
# 5     Appliance F    A high-quality appliance.  336.30          180.0
# 6         Gizmo G               No Description  299.74          113.0
# 7   Contraption H       A high-quality gadget.  144.61          318.0
# 8       Machine I    A high-quality appliance.  285.01            0.0
# 9        Device J               No Description  197.63          497.0
# 10         Tool K         A high-quality tool.    0.00          442.0
# 11      Machine L      A high-quality machine.  486.14           52.0
# 12      Machine M               No Description  425.97          268.0
# 13        Gizmo N  A high-quality contraption.  363.65          295.0
# 14    Apparatus O   A high-quality instrument.  125.63          386.0
# 15       Device P               No Description  135.47          387.0
# 16       Gadget Q      A high-quality machine.   29.81            0.0
# 17      Machine R       A high-quality device.  358.22          113.0
# 18    Apparatus S               No Description   64.34          101.0
# 19       Gadget T       A high-quality gadget.  225.27          113.0
# 20       Device U       A high-quality device.    0.00          440.0
# 21       Widget V               No Description  108.84           81.0
# 22    Appliance W      A high-quality machine.  448.92          187.0
# 23    Apparatus X    A high-quality appliance.  242.93          113.0
# 24   Instrument Y               No Description  286.01            0.0
# 25       Widget Z   A high-quality instrument.  350.80            2.0
# 26    Appliance A   A high-quality instrument.   78.27          130.0
# 27        Gizmo B               No Description  306.16          220.0
# 28  Contraption C       A high-quality widget.  274.52           54.0
# 29         Tool D   A high-quality instrument.  109.50          343.0
# 30   Instrument E               No Description    0.00          485.0
# 31        Gizmo F  A high-quality contraption.  472.00          224.0
# 32       Device G   A high-quality instrument.  303.44            0.0
# 33        Gizmo H               No Description  350.44          225.0
# 34  Contraption I      A high-quality machine.  441.43          385.0
# 35       Device J       A high-quality widget.  315.93          403.0
# 36   Instrument K               No Description  154.86          126.0
# 37  Contraption L      A high-quality machine.   61.69          130.0
# 38       Gadget M      A high-quality machine.  233.70           53.0
# 39         Tool N               No Description  117.04          172.0
# 40   Instrument O        A high-quality gizmo.    0.00            0.0
# 41       Gadget P       A high-quality widget.  214.09          218.0
# 42    Appliance Q               No Description  442.81          160.0
# 43   Instrument R      A high-quality machine.  168.93          198.0
# 44    Appliance S        A high-quality gizmo.   69.82          416.0
# 45       Device T               No Description  184.59          247.0
# 46       Gadget U        A high-quality gizmo.  454.35          324.0
# 47         Tool V       A high-quality widget.  143.34          439.0
# 48  Contraption W               No Description  327.37            0.0
# 49      Machine X       A high-quality device.   10.25          203.0
# 50        Gizmo Y    A high-quality appliance.    0.00          184.0
# 51       Widget Z               No Description  182.76          123.0
# 52         Tool A  A high-quality contraption.  159.34          401.0
# 53       Gadget B    A high-quality appliance.   90.68          255.0
# 54      Machine C               No Description  271.70          294.0
# 55         Tool D   A high-quality instrument.  247.57          280.0
# 56       Gadget E  A high-quality contraption.  349.29            0.0
# 57    Apparatus F               No Description  142.01          325.0
# 58    Apparatus G   A high-quality instrument.  129.62          372.0
# 59    Appliance H      A high-quality machine.   92.46           98.0
#
#          Category
# 0   Miscellaneous
# 1       Apparatus
# 2       Apparatus
# 3         Widgets
# 4     Instruments
# 5   Miscellaneous
# 6       Apparatus
# 7          Gizmos
# 8           Tools
# 9           Tools
# 10  Miscellaneous
# 11         Gizmos
# 12     Appliances
# 13         Gizmos
# 14         Gizmos
# 15  Miscellaneous
# 16          Tools
# 17   Contraptions
# 18          Tools
# 19    Instruments
# 20  Miscellaneous
# 21        Widgets
# 22       Machines
# 23   Contraptions
# 24        Gadgets
# 25  Miscellaneous
# 26       Machines
# 27        Widgets
# 28    Instruments
# 29    Instruments
# 30  Miscellaneous
# 31        Gadgets
# 32   Contraptions
# 33     Appliances
# 34         Gizmos
# 35  Miscellaneous
# 36   Contraptions
# 37     Appliances
# 38    Instruments
# 39          Tools
# 40  Miscellaneous
# 41        Widgets
# 42        Gadgets
# 43        Widgets
# 44        Devices
# 45  Miscellaneous
# 46        Devices
# 47   Contraptions
# 48    Instruments
# 49    Instruments
# 50  Miscellaneous
# 51         Gizmos
# 52         Gizmos
# 53         Gizmos
# 54          Tools
# 55  Miscellaneous
# 56       Machines
# 57      Apparatus
# 58       Machines
# 59        Widgets

# %%
#orders table
orders_df = orders_df.fillna({
    'TotalAmount': 0.0
})
orders_df['OrderDate'] = pd.to_datetime(orders_df['OrderDate'], errors = 'coerce')
orders_df['OrderDate'] = orders_df['OrderDate'].fillna(pd.Timestamp('1970-01-01'))
orders_df['OrderDate'] = orders_df['OrderDate'].dt.strftime('%Y-%m-%d')
#strftime-converts date to given date format
orders_df["OldOrderID"] = range(1001, 1001 + len(orders_df))
#print(orders_df)

#users table
def generate_unique_email(index):
    return f'unknown{index}@example.com'
#index-index number assigned to each row in df
users_df['Email']=users_df.apply(lambda row:row['Email'] if '@' in row['Email'] and '.' in row['Email'] else generate_unique_email(row.name),axis=1)
#row.name-gets the row index number
#axis=1 for checking each row
#axis=0 for checking each column
print(users_df)
# Out:
#   UserName                 Email        Address    Password
# 0   User A  unknown0@example.com   1 Example St   password1
# 1   User B     user1@example.com   2 Example St   password2
# 2   User C     user2@example.com   3 Example St   password3
# 3   User D     user3@example.com   4 Example St   password4
# 4   User E     user4@example.com   5 Example St   password5
# 5   User F  unknown5@example.com   6 Example St   password6
# 6   User G     user6@example.com   7 Example St   password7
# 7   User H     user7@example.com   8 Example St   password8
# 8   User I     user8@example.com   9 Example St   password9
# 9   User J     user9@example.com  10 Example St  password10
# C:\Users\patil\AppData\Local\Temp\ipykernel_18500\2139444354.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   orders_df['OrderDate'] = pd.to_datetime(orders_df['OrderDate'], errors = 'coerce')

# %%
#Payments Table
payments_df=payments_df.fillna(
    {
        'Amount':0.0
    }
)
payments_df['PaymentDate']=pd.to_datetime(payments_df['PaymentDate'],errors='coerce',format='%Y-%m-%d').fillna(pd.Timestamp('1970-01-01'))
payments_df['PaymentDate']=payments_df['PaymentDate'].dt.strftime('%Y-%m-%d')
payments_df['PaymentMethod']=payments_df['PaymentMethod'].replace('InvalidMethod','Unknown')
print(payments_df)

#Reviews table
reviews_df=reviews_df.fillna(
    {
        'ReviewText':'No Review Submitted!'
    }
)
reviews_df['Rating']=reviews_df['Rating'].replace('InvalidRating',0)
reviews_df['Rating']=pd.to_numeric(reviews_df['Rating'])

print("transform Success")
# Out:
#     OrderID PaymentMethod PaymentDate  Amount
# 0      1001       Unknown  1970-01-01    0.00
# 1      1002   Credit Card  2024-08-02  753.48
# 2      1003   Credit Card  2024-08-03  978.27
# 3      1004       Unknown  2024-08-04  564.67
# 4      1005   Credit Card  2024-08-05  390.66
# 5      1006   Credit Card  1970-01-01  815.67
# 6      1007       Unknown  2024-08-07  343.75
# 7      1008   Credit Card  2024-08-08  495.07
# 8      1009   Credit Card  2024-08-09  170.61
# 9      1010       Unknown  2024-08-10  122.82
# 10     1011   Credit Card  1970-01-01    0.00
# 11     1012   Credit Card  2024-08-12  966.38
# 12     1013       Unknown  2024-08-13  852.38
# 13     1014   Credit Card  2024-08-14  726.38
# 14     1015   Credit Card  2024-08-15  468.06
# 15     1016       Unknown  1970-01-01  255.96
# 16     1017   Credit Card  2024-08-17  240.79
# 17     1018   Credit Card  2024-08-18  325.22
# 18     1019       Unknown  2024-08-19  594.30
# 19     1020   Credit Card  2024-08-20  743.14
# 20     1021   Credit Card  1970-01-01    0.00
# 21     1022       Unknown  2024-08-22  694.18
# 22     1023   Credit Card  2024-08-23  351.94
# 23     1024   Credit Card  2024-08-24  959.38
# 24     1025       Unknown  2024-08-25  764.11
# 25     1026   Credit Card  1970-01-01  598.92
# 26     1027   Credit Card  2024-08-27  650.55
# 27     1028       Unknown  2024-08-28  477.64
# 28     1029   Credit Card  2024-08-29  322.96
# 29     1030   Credit Card  2024-08-30  420.38
# 30     1031       Unknown  1970-01-01    0.00
# 31     1032   Credit Card  2024-09-01  782.06
# 32     1033   Credit Card  2024-09-02  112.95
# 33     1034       Unknown  2024-09-03  204.47
# 34     1035   Credit Card  2024-09-04  141.40
# 35     1036   Credit Card  1970-01-01  136.66
# 36     1037       Unknown  2024-09-06  869.91
# 37     1038   Credit Card  2024-09-07  733.29
# 38     1039   Credit Card  2024-09-08  526.76
# 39     1040       Unknown  2024-09-09  188.05
# 40     1041   Credit Card  1970-01-01    0.00
# 41     1042   Credit Card  2024-09-11  542.45
# 42     1043       Unknown  2024-09-12  526.12
# 43     1044   Credit Card  2024-09-13  255.88
# 44     1045   Credit Card  2024-09-14  490.47
# 45     1046       Unknown  1970-01-01  458.65
# 46     1047   Credit Card  2024-09-16  654.27
# 47     1048   Credit Card  2024-09-17  671.58
# 48     1049       Unknown  2024-09-18  140.77
# 49     1050   Credit Card  2024-09-19  437.15
# 50     1051   Credit Card  1970-01-01    0.00
# 51     1052       Unknown  2024-09-21  663.27
# 52     1053   Credit Card  2024-09-22  552.82
# 53     1054   Credit Card  2024-09-23  870.84
# 54     1055       Unknown  2024-09-24  692.82
# 55     1056   Credit Card  1970-01-01  246.64
# 56     1057   Credit Card  2024-09-26  163.51
# 57     1058       Unknown  2024-09-27  678.18
# 58     1059   Credit Card  2024-09-28  123.86
# 59     1060   Credit Card  2024-09-29  627.20
# transform Success

# %%
pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in d:\anaconda\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in d:\anaconda\lib\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Loading data
import mysql.connector
def conn():
    return mysql.connector.connect(
        host = "localhost",
        user = "root",
        password = "Sujay@2002",
        database = "etl"
    )

con = conn()
cursor = con.cursor()
#delete previous records

#list of tables from which data to be cleared
tables_to_clear = ['Payments','Reviews','orders','users','products']

#execute sql query in loop
for table in tables_to_clear:
    cursor.execute(f'delete from {table}')
con.commit() # save changes database

#adding records to product table
product_id_mapping = {} # empty dictionary to store the product_id's

for index, row in Products_df.iterrows():
    # index - index number given to each row
    # row - hold one row at a time
    # iterrows() - iterate/loop through each row
    cursor.execute('''insert into products(product_name, p_description,price,stock_quantity,category) 
    values (%s,%s,%s,%s,%s)''',(row['ProductName'],row['Description'],row['Price'], row['StockQuantity'], row['Category']))
    product_id_mapping[index+1] = cursor.lastrowid
    # [index + 1] - key, lastrowid - value
con.commit()
print(product_id_mapping)

#adding records to user table
user_id_mapping = {}

for index, row in users_df.iterrows():
    cursor.execute('''insert into users(username, email, address, u_password) values (%s,%s,%s,%s)''',
                   (row['UserName'],row['Email'],row['Address'],row['Password']))
    user_id_mapping[index+1] = cursor.lastrowid
con.commit()
print(user_id_mapping)

#adding records to orders table

orders_df['UserID'] = orders_df['UserID'].map(user_id_mapping)
#map() will map the new values to each record
print(orders_df['UserID'])
orders_df = orders_df.dropna(subset = 'UserID')
# if any NULL userID delete the row

order_id_mapping = {}
for index, row in orders_df.iterrows():
    cursor.execute(''' insert into orders(user_id, OrderDate, TotalAmount, Email) values (%s,%s,%s,%s)''',
                   (row['UserID'], row['OrderDate'],row['TotalAmount'],row['Email']))
    order_id_mapping[row['OldOrderID']] = cursor.lastrowid
con.commit()
print(order_id_mapping)

#payments table 
payments_df['OrderID'] = payments_df['OrderID'].map(order_id_mapping)
print(payments_df['OrderID'])
payments_df = payments_df.dropna(subset=["OrderID"])

for index, row in payments_df.iterrows():
    cursor.execute('''insert into payments(orderid, payment_method,payment_date, amount) values (%s,%s,%s,%s)''',
                  (row['OrderID'], row['PaymentMethod'], row['PaymentDate'],row['Amount']))
con.commit()

# reviews table
reviews_df['UserID'] = reviews_df['UserID'].map(user_id_mapping)
reviews_df['ProductID'] = reviews_df['ProductID'].map(product_id_mapping)

for index, row in reviews_df.iterrows():
    product_id = product_id_mapping.get(index)
    user_id = user_id_mapping.get(index)
    cursor.execute('''insert into reviews(productid, userid, rating, review_text) values(%s,%s,%s,%s)''',
                  (int(row['ProductID']), int(row['UserID']), row['Rating'], row['ReviewText']))
print(reviews_df)
print(payments_df)
con.commit()
print("load success")
# Out:
# {1: 841, 2: 842, 3: 843, 4: 844, 5: 845, 6: 846, 7: 847, 8: 848, 9: 849, 10: 850, 11: 851, 12: 852, 13: 853, 14: 854, 15: 855, 16: 856, 17: 857, 18: 858, 19: 859, 20: 860, 21: 861, 22: 862, 23: 863, 24: 864, 25: 865, 26: 866, 27: 867, 28: 868, 29: 869, 30: 870, 31: 871, 32: 872, 33: 873, 34: 874, 35: 875, 36: 876, 37: 877, 38: 878, 39: 879, 40: 880, 41: 881, 42: 882, 43: 883, 44: 884, 45: 885, 46: 886, 47: 887, 48: 888, 49: 889, 50: 890, 51: 891, 52: 892, 53: 893, 54: 894, 55: 895, 56: 896, 57: 897, 58: 898, 59: 899, 60: 900}
# {1: 141, 2: 142, 3: 143, 4: 144, 5: 145, 6: 146, 7: 147, 8: 148, 9: 149, 10: 150}
# 0     148
# 1     144
# 2     141
# 3     148
# 4     144
# 5     146
# 6     148
# 7     144
# 8     143
# 9     149
# 10    143
# 11    149
# 12    142
# 13    142
# 14    142
# 15    146
# 16    143
# 17    149
# 18    144
# 19    141
# 20    144
# 21    141
# 22    145
# 23    144
# 24    148
# 25    148
# 26    147
# 27    143
# 28    141
# 29    141
# 30    143
# 31    146
# 32    147
# 33    146
# 34    146
# 35    146
# 36    143
# 37    146
# 38    148
# 39    142
# 40    145
# 41    141
# 42    141
# 43    145
# 44    143
# 45    144
# 46    143
# 47    141
# 48    141
# 49    145
# 50    146
# 51    143
# 52    149
# 53    145
# 54    148
# 55    141
# 56    145
# 57    143
# 58    141
# 59    144
# Name: UserID, dtype: int64
